# %% [markdown]
# <a href="https://colab.research.google.com/github/y-hiroto2025/neural-network-from-scratch/blob/main/notebooks/04_cross_entropy_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def cross_entropy_error(output, label):
  """
  予測との誤差を計算する
  """
  delta = 1e-7      # オーバーフロー対策

  loss = -np.sum(label * np.log(output + delta))
  return loss
