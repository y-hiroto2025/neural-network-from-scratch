# %% [markdown]
# <a href="https://colab.research.google.com/github/y-hiroto2025/neural-network-from-scratch/blob/main/notebooks/01_affine_layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# 実験
x = np.array([[1.0, 1.0]])
W = np.array([[0.2, 0.3, 0.5],
              [0.4, 0.5, 0.7]])
b = np.array([[0.2, 0.5, 0.2]])

print(np.dot(x, W) + b)
# Out:
# [[0.8 1.3 1.4]]

# %%
# 試しに関数の実装
def affine_trans(x, W, b):
  return np.dot(x, W) + b

# %%
class Affine:
  """
  Fully Connected Layer(Affine Transformation)
  入力データに対して重みとの内積を計算してバイアスを加算する全結合層
  """
  def __init__(self, W, b):
    # W shape       : (input dim, output dim)
    # b shape       : (output dim, )
    self.W = W
    self.b = b

  def forward(self, x):
    # x shape       : (batch size, input dim)
    # output shape  : (batth size, output dim)
    output = np.dot(x, self.W) + self.b
    return output

# %%
layer = Affine(W, b)
print(layer.forward(x))
# Out:
# [[0.8 1.3 1.4]]
